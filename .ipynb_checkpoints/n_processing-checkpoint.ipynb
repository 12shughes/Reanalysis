# %%
import n_calculate_PV_OpenMARS as calc
import glob
import xarray as xr

# %%
opath = '/disco/share/sh1293/OpenMars_data/'
files = glob.glob(opath + '*32*281*')
for file in files:
    print(file)
    initds = xr.open_dataset(file)
    finds, prs = calc.netcdf_prep(initds)
# Out:
# /disco/share/sh1293/OpenMars_data/openmars_my32_ls281_my32_ls300.nc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 6
#       4 print(file)
#       5 initds = xr.open_dataset(file)
# ----> 6 finds, prs = calc.netcdf_prep(initds)
#
# ValueError: too many values to unpack (expected 2)

# %%
finds

# %%
initds
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 72, lat: 36, lev: 35, time: 360)
# Coordinates:
#   * lon      (lon) float32 -180.0 -175.0 -170.0 -165.0 ... 165.0 170.0 175.0
#   * lat      (lat) float32 87.5 82.5 77.5 72.5 67.5 ... -72.5 -77.5 -82.5 -87.5
#   * lev      (lev) float32 0.9995 0.9982 0.9964 ... 0.0001956 5.082e-05
#   * time     (time) float32 5.881e+03 5.881e+03 ... 5.911e+03 5.911e+03
# Data variables:
#     Ls       (time) float32 ...
#     MY       (time) int32 ...
#     ps       (time, lat, lon) float32 ...
#     tsurf    (time, lat, lon) float32 ...
#     co2ice   (time, lat, lon) float32 ...
#     dustcol  (time, lat, lon) float32 ...
#     u        (time, lev, lat, lon) float32 ...
#     v        (time, lev, lat, lon) float32 ...
#     temp     (time, lev, lat, lon) float32 ...
# Attributes: (12/14)
#     Project:                     UPWARDS OpenMARS reanalysis
#     Discipline:                  Planetary Science>Data Assimilation
#     Data_type:                   M1>Modified Data 1
#     Data_version:                1
#     Logical_file_id:             openmars_my32_ls281_my32_ls300
#     Mission_group:               Mars
#     ...                          ...
#     Descriptor:                  MCS>Mars Climate Sounder
#     Instrument_type:             Sounder (space)
#     Logical_source:              MRO_M1_MCS
#     Logical_source_description:  MRO Modified Data MCS
#     Source_name:                 MRO>Mars Reconnaissance Orbiter
#     TEXT:                        Created from a reanalysis of MCS thermal pro...
